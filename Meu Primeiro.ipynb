# %% [markdown]
# <a href="https://colab.research.google.com/github/kowarski/kowarski/blob/main/Meu%20Primeiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introdução ao Pensamento Computacional

# %%
1 print ("Olá")
# Out:
#   File "/tmp/ipython-input-925455899.py", line 1
#     1 print ("Olá")
#       ^
# SyntaxError: invalid syntax
